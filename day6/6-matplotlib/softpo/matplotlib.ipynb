# %% [markdown]
# ### 图片灰度处理

# %% [markdown]
# 三种方法

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = plt.imread('./cat.jpg')
plt.imshow(img)

# %%
# 方式一  最大值、最小值及平均值
img2 = img.mean(axis = 2)
# img.shape

plt.imshow(img2,cmap='gray')

# %%
# 红绿蓝对人眼的敏感度不同
#  0.299  0.587  0.114
w = np.array([0.299,0.587,0.114])

# 方式二 加权平均法(矩阵乘法)
img3 = np.dot(img,w)
plt.imshow(img3,cmap='gray')

# %% [markdown]
# # matplotli

# %% [markdown]
# ## 目录
# + 一、【重点】Matplotlib基础知识
#
# + 二、设置plot的风格和样式
#     + 1、【重点】点和线的样式
#     + 2、X、Y轴坐标刻度
#
#
# + 三、2D图形
#     + 1、示例
#     + 2、【重点】直方图
#     + 3、【重点】条形图
#     + 4、【重点】饼图
#     + 5、【重点】散点图
#
# =============以上为重点=================
#
# #### 下面的自学
# + 四、图形内的文字、注释、箭头
#     + 1、图形内的文字
#     + 2、注释
#     + 3、箭头
#
# + 五、3D图
#     + 1、曲面图

# %% [markdown]
# ## 一、Matplotlib基础知识

# %% [markdown]
# Matplotlib中的基本图表包括的元素
# + x轴和y轴
# 水平和垂直的轴线
#
#
# + x轴和y轴刻度
# 刻度标示坐标轴的分隔，包括最小刻度和最大刻度
#
#
# + x轴和y轴刻度标签
# 表示特定坐标轴的值
#
#
# + 绘图区域
# 实际绘图的区域

# %% [markdown]
# ### 只含单一曲线的图

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x)  # 正弦波
# print(x,y)
'''
plot([x], y, [fmt], data=None, **kwargs)
plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
'''
plt.plot(y)

# %% [markdown]
# ### 包含多个曲线的图

# %% [markdown]
# 1、可以使用多个plot函数（推荐），在一个图中绘制多个曲线

# %%
plt.plot(x,y)
plt.plot(x,np.cos(x))

# %% [markdown]
# 2、也可以在一个plot函数中传入多对X,Y值，在一个图中绘制多个曲线

# %%
line1,line2 = plt.plot(x,y,x,np.cos(x))
line1.set_color('red')

# %% [markdown]
# ### 网格线
# 绘制正选余弦

# %%
plt.plot(x,y)
'''
 linestyle or ls: ['solid' | 'dashed', 'dashdot', 'dotted' | (offset, on-off-dash-seq)
                | ``'-'`` | ``'--'`` | ``'-.'`` | ``':'`` | ``'None'`` | ``' '`` | ``''``]
'''
plt.grid(b = True,axis='both',color='r',linestyle='--',linewidth = 2)

# %% [markdown]
# 使用plt.grid(True)方法为图添加网格线

# %%
plt.plot(x,y)
'''
 linestyle or ls: ['solid' | 'dashed', 'dashdot', 'dotted' | (offset, on-off-dash-seq)
                | ``'-'`` | ``'--'`` | ``'-.'`` | ``':'`` | ``'None'`` | ``' '`` | ``''``]
'''
plt.grid(b = True,axis='both',color='r',linestyle='solid',linewidth = 2)

# %% [markdown]
# 设置grid参数（参数与plot函数相同），使用plt面向对象的方法，创建多个子图显示不同网格线
# ![](1.PNG)
#
# - lw代表linewidth，线的粗细
# - alpha表示线的明暗程度
# - color代表颜色

# %%
fig = plt.figure(figsize=(12,4))

# 向图片中添加子视图axis （轴，x，y） != axes(轴面，子视图)
axes = fig.add_subplot(1,3,1)
axes.plot(x,y)
axes.grid()

axes = fig.add_subplot(1,3,2)
axes.plot(x,y)
axes.grid(color='red',ls = '--')

axes = fig.add_subplot(1,3,3)
axes.plot(x,y)
axes.grid(color='green',ls = '-.',alpha=0.5)

# %% [markdown]
# ### 坐标轴界限

# %% [markdown]
# #### axis方法
# 如果axis方法没有任何参数，则返回当前坐标轴的上下限axis(xmin =,ymax = )

# %%
plt.plot(x,y)
plt.axis([-2,8,-2,2])
# Out:
# [-2, 8, -2, 2]

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 729.5, 455.5, -0.5)

# %% [markdown]
# ##### plt.axis('xxx') 'tight'、'off'、'equal'……
#
# 设置坐标轴类型
# 关闭坐标轴
# ![](2.png)

# %%
x = np.linspace(-1,1,100)
y = (1-x**2)**0.5

plt.plot(x,y,x,-y)

plt.axis('equal')
# Out:
# (-1.1, 1.1, -1.0999438818457405, 1.0999438818457405)

# %%
angle = np.linspace(0,2*np.pi,200)

plt.plot(np.cos(angle),np.sin(angle))
plt.axis('equal')
# Out:
# (-1.09986915899354, 1.0999937694758828, -1.099965731583572, 1.099965731583572)

# %% [markdown]
# #### xlim方法和ylim方法
#
# 除了plt.axis方法，还可以通过xlim，ylim方法设置坐标轴范围

# %%
plt.plot(x,y)

plt.xlim(-2,2)
plt.ylim(0.5,2)
# Out:
# (0.5, 2)

# %% [markdown]
# ### 坐标轴标签
# xlabel方法和ylabel方法
# plt.ylabel('y = x^2 + 5',rotation = 60)旋转

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x)

plt.plot(x,y)
plt.xlabel('X',fontsize=20,color='r')
plt.ylabel('y = sin(x)',fontsize=20,color='green',rotation=80)
# Out:
# Text(0,0.5,'y = sin(x)')

# %% [markdown]
# ### 标题
# title方法

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x)

plt.plot(x,y)
plt.xlabel('X',fontsize=20,color='r')
plt.ylabel('y = sin(x)',fontsize=20,color='green',rotation=80)
plt.title('正弦波',fontproperties='Microsoft YaHei',fontsize=30)
# 四种方式字体设置，其他方式代码多一些，网络查询
# Out:
# Text(0.5,1,'正弦波')

# %% [markdown]
# ### 图例

# %% [markdown]
# #### legend方法
#
# 两种传参方法：
# - 【推荐使用】在plot函数中增加label参数
# - 在legend方法中传入字符串列表
# ![](3.png)

# %%
plt.plot(x,y,label='sin(x)')
plt.plot(x,np.cos(x),label='cos(x)')

plt.legend()

# %%
plt.plot(x,y)
plt.plot(x,np.cos(x))

plt.legend(['sin(x)','cos(x)'])

# %% [markdown]
# label参数为'_xxx'，则图例中不显示
# plt.plot(x, x*1.5, label = '_xxx')

# %% [markdown]
# ### loc参数

# %% [markdown]
# | 字符串       | 数值      | 字符串   |  数值 |
# | :-------------: |:-----------:| :-----:|  :-----:|
# | best        |  0        | center left   |   6 |
# | upper right    | 1        | center right  |   7  |
# | upper left    |  2        | lower center  |   8  |
# | lower left    |  3        | upper center  |   9 |
# | lower right   |  4        | center      |   10 |
# | right       |  5        |

# %%
plt.plot(x,y,label='sin(x)')
plt.plot(x,np.cos(x),label='cos(x)')

plt.legend(loc = 'best')

# %% [markdown]
# loc参数可以是2元素的元组，表示图例左下角的坐标

# %%
plt.plot(x,y,label='sin(x)')
plt.plot(x,np.cos(x),label='cos(x)')

#  1不代表刻度，代表长度或者宽度
plt.legend(loc = (1,0))

# %%
plt.plot(x,y,label='sin(x)')
plt.plot(x,np.cos(x),label='cos(x)')

plt.legend(loc = (0,0),ncol=2)

# %% [markdown]
# 图例也可以超过图的界限loc = (-0.1,0.9)

# %% [markdown]
# ### ncol参数
# ncol控制图例中有几列

# %%
plt.legend(loc = (0,0),ncol=2)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### linestyle、color、marker
# 修改线条样式
# ![](4.png)

# %%
x = np.linspace(0,2*np.pi,20)
y = np.sin(x)

plt.plot(x,y,marker = '*',markersize = 10,color='k',ls='-.')

# %% [markdown]
# ### 保存图片

# %% [markdown]
# figure.savefig的选项
# + filename
# 含有文件路径的字符串或Python的文件型对象。图像格式由文件扩展名推断得出，例如，.pdf推断出PDF，.png推断出PNG
# （“png”、“pdf”、“svg”、“ps”、“eps”……）
# + dpi
# 图像分辨率（每英寸点数），默认为100
# + facecolor
# 图像的背景色，默认为“w”（白色）

# %%
x = np.linspace(0,2*np.pi,20)
y = np.sin(x)

plt.plot(x,y,marker = '*',markersize = 10,color='k',ls='-.')
# 保存图片
plt.savefig('img.pdf',dpi = 100,facecolor='green')

# %%
axes = plt.subplot(111,facecolor='green')

axes.plot(x,y,marker = '*',markersize=20,color='k',markerfacecolor='red')
plt.savefig('img3.jpg')

# %% [markdown]
# ## 二、设置plot的风格和样式
# plot语句中支持除X,Y以外的参数，以字符串形式存在，来控制颜色、线型、点型等要素，语法形式为：
# plt.plot(X, Y, 'format', ...)

# %% [markdown]
# ### 点和线的样式

# %% [markdown]
# #### 颜色
# 参数color或c

# %% [markdown]
# ##### 颜色值的方式
# + 别名
#     + color='r'
#
#
#
# + 合法的HTML颜色名
#     + color = 'red'
#
# | 颜色       | 别名      | HTML颜色名  | 颜色   |  别名 |HTML颜色名|
# | :-------------: |:---------:|:-----------:| :------:|  :-----:| :-----:|
# | 蓝色        | b       | blue      | 绿色   |  g   |  green  |
# | 红色        | r       | red      | 黄色    |  y   |  yellow |
# | 青色        | c       | cyan      | 黑色   |  k   |  black  |
# | 洋红色      | m        | magenta    | 白色   |  w   |  white  |
#
#
#
#
#
#
# + HTML十六进制字符串
#     + color = '#eeefff'
#
#
#
#
# + 归一化到[0, 1]的RGB元组
#     + color = (0.3, 0.3, 0.4)

# %%
# 颜色范围 0~255
0xFF
# Out:
# 255

# %%
plt.plot(x,y,color='#000000')

# %%
# png 颜色范围 0~1
# plt.plot(x,y,color=(0.8,0.0,0.1))
plt.plot(x,y,color=np.random.rand(3))

# %%
plt.plot(x,y,color='purple')

# %% [markdown]
# ##### 透明度
# alpha参数

# %%
plt.plot(x,y,color='red',alpha=0.3)

# %% [markdown]
# ##### 背景色
# 设置背景色，通过plt.subplot()方法传入facecolor参数，来设置坐标轴的背景色

# %%
axes = plt.subplot(facecolor='skyblue')
axes.plot(x,y,color='red',alpha=0.5)

# %% [markdown]
# #### 线型
# 参数linestyle或ls

# %% [markdown]
# | 线条风格     | 描述      | 线条风格 |  描述 |
# | :-------------: |:------------:| :----:|  :-----:|
# | '-'        | 实线     | ':'     |  虚线 |
# | '--'       | 破折线    | 'steps'  |  阶梯线 |
# | '-.'       | 点划线    | 'None' / '，' |  什么都不画 |

# %%
x2 = np.linspace(0,2*np.pi,50)
plt.plot(x2,np.sin(x2),ls='steps')

# %% [markdown]
# ##### 线宽
# linewidth或lw参数

# %%
x2 = np.linspace(0,2*np.pi,50)
plt.plot(x2,np.sin(x2),ls='steps',lw=5)

# %% [markdown]
# ##### 不同宽度的破折线
# dashes参数
# 设置破折号序列各段的宽度
# ![](5.png)

# %%
x2 = np.linspace(0,2*np.pi,50)
# dashes参数，间隔线的长度，间隔长度，间隔线长度，间隔长度.....
plt.plot(x2,np.sin(x2),dashes=[5,3,10,5,1,2])

# %% [markdown]
# #### 点型
# marker参数

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | '1'         | 一角朝下的三脚架      | '3'     |  一角朝左的三脚架 |
# | '2'         | 一角朝上的三脚架      | '4'     |  一角朝右的三脚架 |

# %%
plt.plot(x,y,marker='1',markersize=20)

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | 's'         | 正方形   | 'p'   | 五边形     |
# | 'h'         | 六边形1    | 'H'     | 六边形2    |
# | '8'         | 八边形     |

# %%
plt.plot(x,y,marker='s',markersize=20)

# %%
plt.plot(x,y,marker='8',markersize=20)

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | '.'     |  点 | 'x'   | X   |
# | '\*'    |  星号  | '+'         | 加号       |
# | ','         | 像素       |

# %%
plt.plot(x,y,marker='+',markersize=20)

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | 'o'         | 圆圈      | 'D'         | 菱形      |
# | 'd'    |  小菱形  |'','None',' ',None| 无       |

# %%
plt.plot(x,y,marker='d',markersize=20)

# %% [markdown]
# | 标记     | 描述     | 标记   |  描述 |
# | :--------: |:----------:| :------:| :----:|
# | '\_'     |  水平线    | '&#124;'     |  水平线
# ![](6.png)

# %%
plt.plot(x,y,marker='_',markersize=20)

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | 'v'         | 一角朝下的三角形 | '<'     |  一角朝左的三角形 |
# | '^'         | 一角朝上的三角形 | '>'     |  一角朝右的三角形 |

# %%
plt.plot(x,y,marker='^',markersize=20)

# %% [markdown]
# #### 多参数连用
# 颜色、点型、线型

# %%
plt.plot(x,y,marker=',',markersize=20)

# %% [markdown]
# #### 更多点和线的设置

# %% [markdown]
# | 参数        | 描述       | 参数       |  描述   |
# | :-------------: |:-----------:| :-------------:|  :------:|
# | color或c      | 线的颜色   | linestyle或ls  |  线型   |
# | linewidth或lw   | 线宽     | marker       |  点型  |
# | markeredgecolor  | 点边缘的颜色 | markeredgewidth | 点边缘的宽度 |
# | markerfacecolor  | 点内部的颜色 | markersize    |  点的大小    |
# ![](7.png)

# %%
plt.plot(x,y,color='r',marker='*',markersize=20,markerfacecolor='#00ff00',
         ls='--',lw=2,markeredgecolor='purple',markeredgewidth=2)
# 保存
plt.savefig('./img6.png')
# !!! 调用plt.show() 显示当前图片并创建一个新的视图
plt.show()
plt.axis([-2,8,-1,2])
# Out:
# [-2, 8, -1, 2]

# %% [markdown]
# #### 在一条语句中为多个曲线进行设置

# %% [markdown]
# ##### 多个曲线同一设置
# 属性名声明
#
# plt.plot(x1, y1, x2, y2, fmt, ...)

# %%
plt.plot(x,y,x,np.cos(x),color='#ff0000')

# %% [markdown]
# ##### 多个曲线不同设置
# 多个都进行设置时，无需声明属性
# plt.plot(x1, y1, fmt1, x2, y2, fmt2, ...)

# %%
plt.plot(x,y,'ro-.',x,np.cos(x),'g*:')

# %% [markdown]
# #### 三种设置方式

# %% [markdown]
# ##### 向方法传入关键字参数

# %%
plt.plot(x,y)

# %% [markdown]
# ##### 对实例使用一系列的setter方法

# %%
line, = plt.plot(x,y)
type(line)

line.set_linestyle('--')

# %% [markdown]
# ##### 使用setp()方法

# %%
line, = plt.plot(x,y)

plt.setp(line,color='purple',marker='*',ls='-.')
# Out:
# [None, None, None]

# %% [markdown]
# ### X、Y轴坐标刻度
# xticks()和yticks()方法
# ![](8.png)

# %%
plt.plot(x,y)

plt.yticks([-1,0,1],['min',0,'max'],fontsize=20,color='r')

# 拉丁字母表示，希腊字母表示，$\$
# python  str 格式胡  %d, %f, %s
_=plt.xticks([0,np.pi/2,np.pi,3*np.pi/2,2*np.pi],[0,'$\pi$/2','$\pi$',
                                                  '3$\pi$/2','2$\pi$'])

# %%
plt.plot(x,y)

plt.yticks([-1,0,1],['min',0,'max'],fontsize=20,color='r')

plt.xticks([0,np.pi/2,np.pi,3*np.pi/2,2*np.pi],[0,'$\delta$/2','$\\alpha$',
                                                  '3$\pi$/2','2$\pm$.%0.2f'%(0.23)])
# Out:
# ([<matplotlib.axis.XTick at 0x16874748>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# #### 面向对象方法
# set_xticks、set_yticks、set_xticklabels、set_yticklabels方法

# %% [markdown]
# #### 正弦余弦
# LaTex语法，用$\pi$等表达式在图表上写上希腊字母
# ![](9.png)

# %% [markdown]
# ## 三、2D图形

# %% [markdown]
# ### 直方图
#
# 【直方图的参数只有一个x！！！不像条形图需要传入x,y】
#
# hist()的参数
# + bins
# 可以是一个bin数量的整数值，也可以是表示bin的一个序列。默认值为10
# + normed
# 如果值为True，直方图的值将进行归一化处理，形成概率密度，默认值为False
# + color
# 指定直方图的颜色。可以是单一颜色值或颜色的序列。如果指定了多个数据集合，颜色序列将会设置为相同的顺序。如果未指定，将会使用一个默认的线条颜色
# + orientation
# 通过设置orientation为horizontal创建水平直方图。默认值为vertical

# %%
x = np.random.randint(0,10,size=10)
x
# Out:
# array([5, 7, 7, 7, 5, 5, 3, 1, 7, 6])

# %%
# 统计直方图，统计了各个数据出现的次数
plt.hist(x)
# Out:
# (array([1., 0., 0., 1., 0., 0., 3., 0., 1., 4.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x,bins=10,rwidth=0.5)
# Out:
# (array([1., 0., 0., 1., 0., 0., 3., 0., 1., 4.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x,bins=10,rwidth=0.5,density=True)
# Out:
# (array([0.16666667, 0.        , 0.        , 0.16666667, 0.        ,
#         0.        , 0.5       , 0.        , 0.16666667, 0.66666667]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### 条形图
#
# 【条形图有两个参数x,y！】
#
# bar()、barh()

# %%
plt.hist(x,bins=10,rwidth=0.5,density=False)
# Out:
# (array([1., 0., 0., 1., 0., 0., 3., 0., 1., 4.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <a list of 10 Patch objects>)

# %%
data_x,data_y,_ = plt.hist(x,bins=10,rwidth=0.5,density=False,color='r')

# %%
data_x.shape
# Out:
# (10,)

# %%
data_y.shape
# Out:
# (11,)

# %% [markdown]
# #### 水平条形图
# barh()

# %%
plt.bar(data_x,data_y[1:],width=0.5,align='edge',color=['red','green','purple','black'])
# Out:
# <BarContainer object of 10 artists>

# %%
# plt.barh(data_x[:-1],data_y)

# %%
wind = np.load('./Ravenna_wind.npy')
wind
# Out:
# array([ 10.    ,  20.    ,  40.    ,  90.    ,  87.    ,  79.    ,
#         70.    ,  80.    ,  90.    ,  90.    , 105.    , 100.    ,
#        110.    , 116.504 , 145.001 , 145.001 , 145.001 , 155.503 ,
#        155.503 , 155.503 , 190.    , 126.501 , 250.    ,  99.0009,
#        330.003 ,  20.    ,  70.    ,  70.    ,  10.    ,  80.    ,
#        126.    , 100.    , 135.    , 130.    , 160.    , 130.501 ,
#        190.    , 180.    , 193.502 , 193.502 , 224.004 , 224.004 ,
#        224.004 , 180.    , 190.    , 254.001 , 257.503 , 190.    ,
#        159.5   , 100.    ,  80.    ,  90.    ,  80.    ,  80.    ,
#         90.    ,  90.    ,  90.    ,  97.    ,  89.    ,  88.0147,
#        107.004 , 107.004 , 132.503 , 132.503 , 132.503 , 251.    ])

# %%
plt.hist(wind,bins=8,range=[0,360],rwidth=0.5,align='mid')
# Out:
# (array([ 5., 12., 24.,  9., 11.,  4.,  0.,  1.]),
#  array([  0.,  45.,  90., 135., 180., 225., 270., 315., 360.]),
#  <a list of 8 Patch objects>)

# %%
# 根据数据的划分范围将数据分成固定份数，统计数据的出现次数
wind_count,wind_range = np.histogram(wind,bins=8,range=[0,360])

# %%
# 条形图， 和直方图类似
plt.bar(wind_range[:-1],wind_count,width=30)
# Out:
# <BarContainer object of 8 artists>

# %%
wind_range
# Out:
# array([  0.,  45.,  90., 135., 180., 225., 270., 315., 360.])

# %%
# 玫瑰图，极坐标图
x = np.arange(0,2*np.pi,np.pi/4)

# %%
plt.figure(figsize=(5,5))
plt.axes(polar=True,facecolor='gray')
plt.bar(x,wind_count,width=np.pi/4,color=np.random.rand(8,3))
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# ### 饼图
#
# 【饼图也只有一个参数x！】
#
# pie()
# 饼图适合展示各部分占总体的比例，条形图适合比较各部分的大小

# %%
plt.pie([0.3,0.4,0.15,0.15])
plt.axis('equal')
# Out:
# (-1.1000000222348558,
#  1.1000000320149983,
#  -1.113611536756788,
#  1.1136115368643837)

# %% [markdown]
# 普通各部分占满饼图

# %%
plt.pie([0.3,0.4,0.15])
plt.axis('equal')
# Out:
# (-1.100000020757401,
#  1.1000000009884476,
#  -1.113611536756788,
#  1.1136115368643837)

# %% [markdown]
# 普通未占满饼图

# %% [markdown]
# 饼图阴影、分裂等属性设置
# #labels参数设置每一块的标签；labeldistance参数设置标签距离圆心的距离（比例值）
# #autopct参数设置比例值的显示格式(%1.1f%%)；pctdistance参数设置比例值文字距离圆心的距离
# #explode参数设置每一块顶点距圆形的长度（比例值）；colors参数设置每一块的颜色；
# #shadow参数为布尔值，设置是否绘制阴影

# %%
x = [0.3,0.25,0.25,0.1,0.2]

y = ['dog','cat','fish','turtle','snake']
plt.figure(figsize=(5,5))
_ = plt.pie(x,labels=y,autopct='%0.1f%%',
            labeldistance=0.5,
            explode=[0,0.1,0,0,0.2],
            colors=np.random.rand(5,3),
            shadow=True,startangle=90)

# %% [markdown]
# startangle设置旋转角度

# %% [markdown]
# ### 散点图
#
# 【散点图需要两个参数x,y，但此时x不是表示x轴的刻度，而是每个点的横坐标！】
#
# scatter()
# ![](10.png)

# %%
from pandas import Series,DataFrame

# %%
df = DataFrame(np.random.randint(0,150,size=(50,2)),columns=['python','math'])
df
# Out:
#     python  math
# 0      121    30
# 1      148   128
# 2       41    31
# 3      128     0
# 4       92    94
# 5      138   121
# 6        7    82
# 7       21    23
# 8      145   136
# 9        7   138
# 10      44    39
# 11      15   118
# 12     139    12
# 13      70    30
# 14     121   104
# 15      24   144
# 16      42    44
# 17      82    78
# 18      23   130
# 19      96   127
# 20      16    69
# 21     105    27
# 22     123    15
# 23     113   119
# 24      81    69
# 25       9    63
# 26       9   105
# 27      64    13
# 28      27    97
# 29      50    44
# 30     116    28
# 31     101    85
# 32     138   142
# 33      79   138
# 34     124    66
# 35      83    57
# 36      92    12
# 37      75    84
# 38      51   115
# 39      82    55
# 40      11     4
# 41       4   148
# 42      97    46
# 43      84    88
# 44      67    81
# 45      78    60
# 46       6   119
# 47      66    39
# 48     125    47
# 49      63   103

# %%
# python 与 math 没有关系
plt.scatter(df['python'],df['math'])

# %%
df['en'] = df['python'].map(lambda x:x*0.7 + np.random.randint(-10,10,size=1)[0])
df
# Out:
#     python  math     en
# 0      121    30   80.7
# 1      148   128   99.6
# 2       41    31   25.7
# 3      128     0   85.6
# 4       92    94   56.4
# 5      138   121   98.6
# 6        7    82   12.9
# 7       21    23   11.7
# 8      145   136  110.5
# 9        7   138   -0.1
# 10      44    39   24.8
# 11      15   118    8.5
# 12     139    12   92.3
# 13      70    30   41.0
# 14     121   104   77.7
# 15      24   144    6.8
# 16      42    44   24.4
# 17      82    78   58.4
# 18      23   130    6.1
# 19      96   127   68.2
# 20      16    69   15.2
# 21     105    27   65.5
# 22     123    15   77.1
# 23     113   119   86.1
# 24      81    69   65.7
# 25       9    63    2.3
# 26       9   105   -2.7
# 27      64    13   45.8
# 28      27    97   15.9
# 29      50    44   32.0
# 30     116    28   75.2
# 31     101    85   75.7
# 32     138   142   96.6
# 33      79   138   62.3
# 34     124    66   82.8
# 35      83    57   55.1
# 36      92    12   73.4
# ...

# %%
plt.scatter(df['python'],df['en'],c=['red','blue'],s=20)

# %% [markdown]
# ## <font color = red>四、图形内的文字、注释、箭头(自学)</font>

# %% [markdown]
# 控制文字属性的方法:
#
#
# | Pyplot函数     | API方法                | 描述                     |
# | :-------------: |:------------------------------:| :---------------------------------:|
# | text()       |  mpl.axes.Axes.text()       | 在Axes对象的任意位置添加文字     |
# | xlabel()      |  mpl.axes.Axes.set_xlabel()   | 为X轴添加标签               |
# | ylabel()      |  mpl.axes.Axes.set_ylabel()   | 为Y轴添加标签               |
# | title()       | mpl.axes.Axes.set_title()   |  为Axes对象添加标题            |
# | legend()      | mpl.axes.Axes.legend()      |  为Axes对象添加图例            |
# | figtext()     |  mpl.figure.Figure.text()    |  在Figure对象的任意位置添加文字    |
# | suptitle()     | mpl.figure.Figure.suptitle() |  为Figure对象添加中心化的标题     |
# | annnotate()    |  mpl.axes.Axes.annotate()    |  为Axes对象添加注释（箭头可选）    |
#
#
# 所有的方法会返回一个matplotlib.text.Text对象

# %% [markdown]
# ### 图形内的文字
# text()
# ![](14.png)

# %% [markdown]
# 使用figtext()

# %% [markdown]
# ### 注释
# annotate()
# xy参数设置箭头指示的位置，xytext参数设置注释文字的位置
# arrowprops参数以字典的形式设置箭头的样式
# width参数设置箭头长方形部分的宽度，headlength参数设置箭头尖端的长度，
# headwidth参数设置箭头尖端底部的宽度，
# facecolor设置箭头颜色
# shrink参数设置箭头顶点、尾部与指示点、注释文字的距离（比例值）
# ![](15.png)

# %% [markdown]
# 练习
# 三个随机正太分布数据
# ![](16.png)
# 设置图例
# bbox_to_anchor,ncol mode,borderaxespad
# 设置注解 arrowstyle

# %% [markdown]
# ### 箭头
# 箭头的样式，没必要记

# %%
plt.figure(figsize=(12,9))
plt.axis([0, 10, 0, 20]);
arrstyles = ['-', '->', '-[', '<-', '<->', 'fancy', 'simple', 'wedge']
for i, style in enumerate(arrstyles):
    plt.annotate(style, xytext=(1, 2+2*i), xy=(4, 1+2*i), arrowprops=dict(arrowstyle=style));

connstyles=["arc", "arc,angleA=10,armA=30,rad=30", "arc3,rad=.2", "arc3,rad=-.2", "angle", "angle3"]
for i, style in enumerate(connstyles):
    plt.annotate(style, xytext=(6, 2+2*i), xy=(8, 1+2*i), arrowprops=dict(arrowstyle='->', connectionstyle=style));
plt.show()

# %% [markdown]
# ## <font color = red>五、3D图(自学)</font>

# %% [markdown]
# #### 曲面图
# ![](11.png)

# %% [markdown]
# 导包
# from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
# 散点图
fig = plt.figure(figsize=(8,6))
axes3D = Axes3D(fig)
x = np.random.randint(0,50,size=100)
y = np.random.randint(0,50,size=100)
z = np.random.randint(-50,0,size=100)

axes3D.scatter3D(x,y,z,s=50)
axes3D.set_xlabel('X',fontsize=30)
axes3D.set_zlabel('Z',fontsize=30,color='r')

axes3D.set_yticks([0,20,40,60,80])

# %%
# 线形图
fig = plt.figure(figsize=(8,6))
axes3D = Axes3D(fig)

x = np.linspace(0,20,300)
# y = np.sin(x)
# z = np.cos(x)
y = np.linspace(-20,0,300)
z = (x**2 + y**2/2)**0.5
axes3D.scatter3D(x,y,z)

# %%
# 绘制面
fig = plt.figure(figsize=(8,6))
axes3D = Axes3D(fig)

x = np.linspace(-2,2,100)
y = np.linspace(-2,2,100)
# z = np.power((x**2 + y**2),0.5)

X,Y = np.meshgrid(x,y)
Z = (X**2 + Y**2)**0.5
axes3D.plot_surface(X,Y,Z,cmap='rainbow')

# %%
display(X.shape)
# Out:
# (100, 100)

# %%
a = np.linspace(1,3,30)
b = np.linspace(-6,0,30)
plt.scatter(a,b)

# %%
a = np.array([1,2,3,5])
b = np.array([-2,-4,-6])

A,B = np.meshgrid(a,b)
display(A,B)
# Out:
# array([[1, 2, 3, 5],
#        [1, 2, 3, 5],
#        [1, 2, 3, 5]])
# array([[-2, -2, -2, -2],
#        [-4, -4, -4, -4],
#        [-6, -6, -6, -6]])

# %%
A,B = np.meshgrid(a,b)
plt.scatter(A,B)

# %%
# 绘制三维柱状图
fig = plt.figure(figsize=(8,6))
axes3D = Axes3D(fig)

for i in range(6):
    x = np.arange(0,10)
    y = np.random.randint(0,20,size=10)
    axes3D.bar(x,y,zs=i,zdir = 'x')

axes3D.set_xlabel('X',fontsize=20)
axes3D.set_ylabel('Y',fontsize=20)
axes3D.set_zlabel('Z',fontsize=20)

axes3D.set_xticks([0,1,2,3,4,5])

axes3D.set_xticklabels(['2000','2004','2008','2012','2016','2018'])
# axes3D.set_yticks([0,])
# Out:
# [Text(0,0,'2000'),
#  Text(0,0,'2004'),
#  Text(0,0,'2008'),
#  Text(0,0,'2012'),
#  Text(0,0,'2016'),
#  Text(0,0,'2018')]

# %%
# 混合3D图形

# 散点图
fig = plt.figure(figsize=(8,6))
axes3D = Axes3D(fig)
x = np.random.randint(0,50,size=100)
y = np.random.randint(0,50,size=100)
z = np.random.randint(-50,0,size=100)

axes3D.scatter3D(x,y,z,s=50)
axes3D.set_xlabel('X',fontsize=30)
axes3D.set_zlabel('Z',fontsize=30,color='r')

axes3D.set_yticks([0,20,40,60,80])

# 
x = np.linspace(0,50,200)
y = np.linspace(0,50,200)
z = (np.sin(x) + np.cos(x))*50

axes3D.plot(x,y,z,color='r')

# %%
plt.figure(figsize=(12,6))
axes3d = plt.subplot(1,3,1,projection= '3d')

x = np.random.randint(0,50,size=100)
y = np.random.randint(0,50,size=100)
z = np.random.randint(-50,0,size=100)

axes3d.scatter(x,y,z)

axes3d = plt.subplot(1,3,2,projection= '3d')
x = np.linspace(-2,2,100)
y = np.linspace(-2,2,100)

X,Y = np.meshgrid(x,y)
Z = (X**2 + Y**2)**0.5

axes3d.plot_surface(X,Y,Z)

axes3d = plt.subplot(1,3,3,projection = '3d')

t= np.linspace(0,2*np.pi,100)
p = np.linspace(0,2*np.pi,100)
T,P = np.meshgrid(t,p)

X = np.sin(P)*np.cos(T)
Y = np.sin(P)*np.sin(T)
Z = np.cos(P)

axes3d.plot_surface(X,Y,Z,cmap = 'rainbow')

# %% [markdown]
# 生成数据

# %% [markdown]
# 绘制图形

# %% [markdown]
# ## <font color = red>玫瑰图/极坐标条形图(自学)</font>
# ![](13.png)

# %% [markdown]
# 创建极坐标条形图

# %% [markdown]
# 使用np.histogram计算一组数据的直方图
